# %%
import math
import pandas as pd

# Modify here
num_readlines = math.inf

# Given Data
obsolete_GOs = ['GO:0046658', 'GO:0005779', 'GO:0015299', 'GO:0031305', 'GO:0030176', 'GO:0097056', 'GO:0099056', 'GO:0006471', 'GO:0008022', 'GO:0031225', 'GO:0140289', 'GO:0005639', 'GO:0046916', 'GO:0099055', 'GO:0030176']
taxon_to_clade = {'cellular organisms': 'cellular organisms', 'Eukaryota': 'Eukaryota', 'Opisthokonta': 'Eukaryota', 'Metazoa': 'Metazoa', 'Eumetazoa': 'Metazoa', 'Bilateria': 'Metazoa', 'Deuterostomia': 'Metazoa', 'Chordata': 'Chordata', 'Craniata': 'Chordata', 'Vertebrata': 'Chordata', 'Gnathostomata': 'Chordata', 'Teleostomi': 'Chordata', 'Euteleostomi': 'Chordata', 'Sarcopterygii': 'Chordata', 'Dipnotetrapodomorpha': 'Chordata', 'Tetrapoda': 'Chordata', 'Amniota': 'Chordata', 'Mammalia': 'Mammalia', 'Theria': 'Mammalia', 'Eutheria': 'Mammalia', 'Boreoeutheria': 'Mammalia', 'Euarchontoglires': 'Mammalia', 'Primates': 'Primates', 'Haplorrhini': 'Primates', 'Simiiformes': 'Primates', 'Catarrhini': 'Primates', 'Hominoidea': 'Primates', 'Hominidae': 'Hominidae', 'Homininae': 'Hominidae', 'Homo': 'Homo', 'Homo sapiens': 'Homo sapiens'}


fn = "human-higher-pLddt-repId_nMem_repLen_avgLen_varLen_repPlddt_avgPlddt_varPlddt_taxId_rank_rankName_link_sapId-sapPlddt-sapGO.tsv"
fn = "clu-sap-repId_lcaTaxId_lcaRankName_sapId_sapPlddt_sapGO.tsv"
f = open(f"../homo_sapiens/{fn}")

# internal
go_diversity = set()
go_frequency = {}

# output data
data = {'repId': [], 'sapId': [], 'lca_clade': [], 'GO_function': [], 'lca_taxon': []}
pd_data = pd.DataFrame(columns = ['organism', 'rank', 'GO_function'])

n = 0
while True:
    line = f.readline().strip()
    n += 1
    
    if n >= num_readlines:
        break
    if not line:
        break
        
    tokens = line.split("\t")

    repId = tokens[0]
    lca_taxon = tokens[2]
    sapId = tokens[3]
    go_function = tokens[5]

    if go_function in obsolete_GOs:
        continue
    
    data['repId'].append(repId)
    data['sapId'].append(sapId)
    data['lca_clade'].append(taxon_to_clade[lca_taxon])
    data['lca_taxon'].append(lca_taxon)
    data['GO_function'].append(go_function)
    
    # generate internal data for analysis
    go_diversity.add(go_function)
    if not go_frequency.get(go_function):
        go_frequency[go_function]=1
    else:
        go_frequency[go_function]+=1

f.close()
pd_data = pd.DataFrame(data)
print(len(go_diversity))
print(len(data['lca_taxon']))
# Out:
# 9683
# 56815

# %%
pd_data
# Out:
#                                repId                      sapId  \
# 0      AF-A0A212DI27-F1-model_v3.cif  AF-Q4AC99-F1-model_v3.cif
# 1      AF-A0A212DI27-F1-model_v3.cif  AF-Q4AC99-F1-model_v3.cif
# 2      AF-A0A212DI27-F1-model_v3.cif  AF-Q4AC99-F1-model_v3.cif
# 3      AF-A0A212DI27-F1-model_v3.cif  AF-Q4AC99-F1-model_v3.cif
# 4      AF-A0A453G0Q8-F1-model_v3.cif  AF-P30153-F1-model_v3.cif
# ...                              ...                        ...
# 56810  AF-A0A453PE91-F1-model_v3.cif  AF-B4E108-F1-model_v3.cif
# 56811  AF-A0A453PE91-F1-model_v3.cif  AF-B4E108-F1-model_v3.cif
# 56812      AF-B7Z6L1-F1-model_v3.cif  AF-B7Z6L1-F1-model_v3.cif
# 56813      AF-B7Z6L1-F1-model_v3.cif  AF-B7Z6L1-F1-model_v3.cif
# 56814      AF-B7Z6L1-F1-model_v3.cif  AF-B7Z6L1-F1-model_v3.cif
#
#                 lca_clade GO_function           lca_taxon
# 0      cellular organisms  GO:0030170  cellular organisms
# 1      cellular organisms  GO:0008483  cellular organisms
# 2      cellular organisms  GO:0009058  cellular organisms
# 3      cellular organisms  GO:0006520  cellular organisms
# 4      cellular organisms  GO:0000775  cellular organisms
# ...                   ...         ...                 ...
# 56810           Eukaryota  GO:0046872           Eukaryota
# 56811           Eukaryota  GO:0006002           Eukaryota
# 56812            Chordata  GO:0016459        Euteleostomi
# 56813            Chordata  GO:0003779        Euteleostomi
# 56814            Chordata  GO:0007605        Euteleostomi
#
# [56815 rows x 5 columns]

# %%
from goatools.base import get_godag
from goatools.gosubdag.gosubdag import GoSubDag
from goatools.godag.go_tasks import get_go2parents, get_go2parents_isa
from goatools.obo_parser import GODag

godag = get_godag('go-basic.obo', optional_attrs="relationship")
output = {'repId': [], 'sapId': [], 'GO_function': [], 'lca_taxon': []}

n = 0
cycle = len(pd_data['GO_function'])
# cycle = 100

for i in range(cycle):
    if i / cycle * 100 > n:
        print(f"percentage: {i/cycle*100}%")
        n+=1
    
    goid = pd_data['GO_function'][i]
    rank = pd_data['lca_clade'][i]
    repId = pd_data['repId'][i]
    sapId = pd_data['sapId'][i]
    lca = pd_data['lca_taxon'][i]

    gosubdag = GoSubDag(goid, godag, relationships=True, prt=False)

    try:
      ntgo = gosubdag.go2nt[goid]
    except:
      print(f"error {goid}")
      continue

    go2parents = get_go2parents_isa(gosubdag.go2obj)
    
    s = [goid]
    traversed = {}
    
    while s:
        cur = s.pop()
        
        if cur == 'GO:0002376':
            output['repId'].append(repId)
            output['sapId'].append(sapId)
            output['GO_function'].append(goid)
            output['lca_taxon'].append(lca)
            break
        try:
          cur_function = godag[cur].name
        except:
           print(f"error in the tree of {goid} with {cur}")
           continue
        
        if traversed.get(cur):
            continue
        traversed[cur] = rank
        
        
        if not go2parents.get(cur):
            continue
            
        for next in go2parents[cur]:
            s.append(next)

print(f"percentage: 100%")
# Out:
#   EXISTS: go-basic.obo
# go-basic.obo: fmt(1.2) rel(2023-04-01) 46,575 Terms; optional_attrs(relationship)
# percentage: 0.001760098565519669%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031307
# error GO:0031307
# 1 GO IDs NOT FOUND IN GO DAG: GO:0033561
# error GO:0033561
# percentage: 1.0014960837806917%
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001161
# error GO:2001161
# percentage: 2.001232068995864%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044214
# error GO:0044214
# 1 GO IDs NOT FOUND IN GO DAG: GO:0100002
# error GO:0100002
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 3.0009680542110355%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000737
# error GO:0000737
# percentage: 4.000704039426208%
# percentage: 5.00044002464138%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031227
# error GO:0031227
# percentage: 6.000176009856552%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071556
# error GO:0071556
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001020
# error GO:2001020
# percentage: 7.001672093637244%
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001022
# error GO:2001022
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# percentage: 8.001408078852416%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0048478
# error GO:0048478
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044214
# error GO:0044214
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031307
# error GO:0031307
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 9.001144064067587%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# percentage: 10.00088004928276%
# percentage: 11.00061603449793%
# percentage: 12.000352019713104%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# percentage: 13.000088004928276%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010767
# error GO:0010767
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 14.001584088708968%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0006165
# error GO:0006165
# percentage: 15.001320073924141%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031304
# error GO:0031304
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055065
# error GO:0055065
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 16.001056059139312%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070940
# error GO:0070940
# percentage: 17.000792044354483%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 18.000528029569658%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0043486
# error GO:0043486
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031307
# error GO:0031307
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 20.00176009856552%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 21.00149608378069%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010259
# error GO:0010259
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099061
# error GO:0099061
# percentage: 22.00123206899586%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0097631
# error GO:0097631
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099061
# error GO:0099061
# percentage: 23.000968054211036%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044214
# error GO:0044214
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010259
# error GO:0010259
# 1 GO IDs NOT FOUND IN GO DAG: GO:0033683
# error GO:0033683
# 1 GO IDs NOT FOUND IN GO DAG: GO:0006296
# error GO:0006296
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031227
# error GO:0031227
# percentage: 24.000704039426207%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0033692
# error GO:0033692
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031224
# error GO:0031224
# percentage: 25.000440024641378%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# percentage: 26.000176009856553%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 27.00167209363724%
# percentage: 28.001408078852414%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099060
# error GO:0099060
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099144
# error GO:0099144
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 29.001144064067585%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0097573
# error GO:0097573
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 30.000880049282756%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0102343
# error GO:0102343
# 1 GO IDs NOT FOUND IN GO DAG: GO:0102344
# error GO:0102344
# 1 GO IDs NOT FOUND IN GO DAG: GO:0102345
# error GO:0102345
# 1 GO IDs NOT FOUND IN GO DAG: GO:0102158
# error GO:0102158
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031362
# error GO:0031362
# percentage: 31.00061603449793%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010259
# error GO:0010259
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071556
# error GO:0071556
# percentage: 32.000352019713105%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031307
# error GO:0031307
# percentage: 33.00008800492827%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010259
# error GO:0010259
# percentage: 34.00158408870897%
# percentage: 35.00132007392414%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0046855
# error GO:0046855
# 1 GO IDs NOT FOUND IN GO DAG: GO:0046855
# error GO:0046855
# 1 GO IDs NOT FOUND IN GO DAG: GO:0052746
# error GO:0052746
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 36.001056059139316%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099699
# error GO:0099699
# 1 GO IDs NOT FOUND IN GO DAG: GO:0052746
# error GO:0052746
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001253
# error GO:2001253
# percentage: 37.00079204435448%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0006165
# error GO:0006165
# 1 GO IDs NOT FOUND IN GO DAG: GO:1900051
# error GO:1900051
# 1 GO IDs NOT FOUND IN GO DAG: GO:0035574
# error GO:0035574
# percentage: 38.00052802956966%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031301
# error GO:0031301
# percentage: 39.00026401478483%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010847
# error GO:0010847
# percentage: 40.00176009856552%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0032199
# error GO:0032199
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099061
# error GO:0099061
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099059
# error GO:0099059
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031226
# error GO:0031226
# percentage: 41.001496083780694%
# percentage: 42.00123206899586%
# percentage: 43.000968054211036%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 44.00070403942621%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044026
# error GO:0044026
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099061
# error GO:0099061
# 1 GO IDs NOT FOUND IN GO DAG: GO:0061732
# error GO:0061732
# percentage: 45.00044002464138%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031235
# error GO:0031235
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000737
# error GO:0000737
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# percentage: 46.00017600985655%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0006165
# error GO:0006165
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001020
# error GO:2001020
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 47.00167209363724%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0051692
# error GO:0051692
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099060
# error GO:0099060
# 1 GO IDs NOT FOUND IN GO DAG: GO:0089717
# error GO:0089717
# percentage: 48.001408078852414%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001022
# error GO:2001022
# percentage: 49.00114406406759%
# 1 GO IDs NOT FOUND IN GO DAG: GO:1904486
# error GO:1904486
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099029
# error GO:0099029
# 1 GO IDs NOT FOUND IN GO DAG: GO:0061732
# error GO:0061732
# 1 GO IDs NOT FOUND IN GO DAG: GO:1903118
# error GO:1903118
# percentage: 50.000880049282756%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0004652
# error GO:0004652
# 1 GO IDs NOT FOUND IN GO DAG: GO:0004652
# error GO:0004652
# percentage: 51.00061603449794%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000416
# error GO:0000416
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001022
# error GO:2001022
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# percentage: 52.000352019713105%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0035574
# error GO:0035574
# percentage: 53.00008800492828%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0046939
# error GO:0046939
# percentage: 54.00158408870897%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# 1 GO IDs NOT FOUND IN GO DAG: GO:2001255
# error GO:2001255
# 1 GO IDs NOT FOUND IN GO DAG: GO:1905437
# error GO:1905437
# percentage: 55.00132007392414%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031362
# error GO:0031362
# 1 GO IDs NOT FOUND IN GO DAG: GO:1901675
# error GO:1901675
# 1 GO IDs NOT FOUND IN GO DAG: GO:1901675
# error GO:1901675
# percentage: 56.00105605913931%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0098993
# error GO:0098993
# percentage: 57.00079204435448%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000737
# error GO:0000737
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000738
# error GO:0000738
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# percentage: 58.00052802956965%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031224
# error GO:0031224
# percentage: 59.00026401478483%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044262
# error GO:0044262
# percentage: 60.00176009856551%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031362
# error GO:0031362
# percentage: 61.001496083780694%
# 1 GO IDs NOT FOUND IN GO DAG: GO:1905103
# error GO:1905103
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031226
# error GO:0031226
# 1 GO IDs NOT FOUND IN GO DAG: GO:0036254
# error GO:0036254
# 1 GO IDs NOT FOUND IN GO DAG: GO:0097274
# error GO:0097274
# percentage: 62.00123206899586%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010259
# error GO:0010259
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000737
# error GO:0000737
# percentage: 63.000968054211036%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099061
# error GO:0099061
# percentage: 64.00070403942621%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# percentage: 65.00044002464138%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031307
# error GO:0031307
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071458
# error GO:0071458
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071556
# error GO:0071556
# 1 GO IDs NOT FOUND IN GO DAG: GO:0043486
# error GO:0043486
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010847
# error GO:0010847
# percentage: 66.00017600985655%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031235
# error GO:0031235
# 1 GO IDs NOT FOUND IN GO DAG: GO:0004652
# error GO:0004652
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030285
# error GO:0030285
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030285
# error GO:0030285
# percentage: 67.00167209363724%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031309
# error GO:0031309
# 1 GO IDs NOT FOUND IN GO DAG: GO:0099066
# error GO:0099066
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030285
# error GO:0030285
# percentage: 68.00140807885242%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# percentage: 69.00114406406759%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0035511
# error GO:0035511
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070816
# error GO:0070816
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070816
# error GO:0070816
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070816
# error GO:0070816
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# percentage: 70.00088004928276%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0004083
# error GO:0004083
# 1 GO IDs NOT FOUND IN GO DAG: GO:0048478
# error GO:0048478
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044262
# error GO:0044262
# percentage: 71.00061603449794%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0044214
# error GO:0044214
# 1 GO IDs NOT FOUND IN GO DAG: GO:0032592
# error GO:0032592
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 72.0003520197131%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031226
# error GO:0031226
# percentage: 73.00008800492827%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0047485
# error GO:0047485
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031226
# error GO:0031226
# 1 GO IDs NOT FOUND IN GO DAG: GO:0008853
# error GO:0008853
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000738
# error GO:0000738
# percentage: 74.00158408870897%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031226
# error GO:0031226
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# 1 GO IDs NOT FOUND IN GO DAG: GO:0006165
# error GO:0006165
# percentage: 75.00132007392413%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0010216
# error GO:0010216
# 1 GO IDs NOT FOUND IN GO DAG: GO:0097635
# error GO:0097635
# 1 GO IDs NOT FOUND IN GO DAG: GO:0000306
# error GO:0000306
# percentage: 76.00105605913932%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0031301
# error GO:0031301
# percentage: 77.00079204435448%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0030173
# error GO:0030173
# percentage: 78.00052802956967%
# percentage: 80.00176009856553%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0048478
# error GO:0048478
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070895
# error GO:0070895
# percentage: 81.0014960837807%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0007568
# error GO:0007568
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 82.00123206899586%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0004652
# error GO:0004652
# percentage: 83.00096805421103%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0097573
# error GO:0097573
# percentage: 84.00070403942621%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 85.00044002464138%
# percentage: 86.00017600985656%
# percentage: 87.00167209363724%
# percentage: 88.00140807885242%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 89.00114406406759%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070816
# error GO:0070816
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 90.00088004928276%
# percentage: 91.00061603449792%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071556
# error GO:0071556
# percentage: 92.0003520197131%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071458
# error GO:0071458
# 1 GO IDs NOT FOUND IN GO DAG: GO:0071556
# error GO:0071556
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# 1 GO IDs NOT FOUND IN GO DAG: GO:0070816
# error GO:0070816
# percentage: 93.00008800492827%
# percentage: 94.00158408870897%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0018024
# error GO:0018024
# percentage: 95.00132007392415%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0046855
# error GO:0046855
# percentage: 96.00105605913932%
# percentage: 97.00079204435448%
# 1 GO IDs NOT FOUND IN GO DAG: GO:0055072
# error GO:0055072
# percentage: 98.00052802956965%
# percentage: 99.00026401478483%
# percentage: 100%

# %%
print(output)
# Out:
# {'repId': ['AF-A0A5K4FB41-F1-model_v3.cif', 'AF-A0A6G0TTL2-F1-model_v3.cif', 'AF-A0A498LQC5-F1-model_v3.cif', 'AF-A0A498LQC5-F1-model_v3.cif', 'AF-A0A6P8G6G5-F1-model_v3.cif', 'AF-A0A4X2JZY5-F1-model_v3.cif', 'AF-A0A286S9Y4-F1-model_v3.cif', 'AF-A0A286S9Y4-F1-model_v3.cif', 'AF-A0A286S9Y4-F1-model_v3.cif', 'AF-A0A286S9Y4-F1-model_v3.cif', 'AF-T1JFE5-F1-model_v3.cif', 'AF-D3ZV49-F1-model_v3.cif', 'AF-D3ZV49-F1-model_v3.cif', 'AF-D3ZV49-F1-model_v3.cif', 'AF-D3ZV49-F1-model_v3.cif', 'AF-D3ZV49-F1-model_v3.cif', 'AF-A0A4Y9FT94-F1-model_v3.cif', 'AF-A0A6P4T4H1-F1-model_v3.cif', 'AF-A0A6P4T4H1-F1-model_v3.cif', 'AF-A0A6A2WU80-F1-model_v3.cif', 'AF-A0A6A2WU80-F1-model_v3.cif', 'AF-A0A507F0Z4-F1-model_v3.cif', 'AF-A0A7C4C840-F1-model_v3.cif', 'AF-A0A7C4C840-F1-model_v3.cif', 'AF-A0A2K3CX85-F1-model_v3.cif', 'AF-Q55DL8-F1-model_v3.cif', 'AF-A0A4X2L807-F1-model_v3.cif', 'AF-A0A3M7RS47-F1-model_v3.cif', 'AF-A0A3M7RS47-F1-model_v3.cif', 'AF-A0A2R7WKF9-F1-model_v3.cif', 'AF-A0A1I8F4V4-F1-model_v3.cif', 'AF-A0A6P4TKL6-F1-model_v3.cif', 'AF-A0A6P4TKL6-F1-model_v3.cif', 'AF-A0A3B4AXE3-F1-model_v3.cif', 'AF-A0A6B9KD00-F1-model_v3.cif', 'AF-A0A6B9KD00-F1-model_v3.cif', 'AF-A0A6B9KD00-F1-model_v3.cif', 'AF-A0A6B9KD00-F1-model_v3.cif', 'AF-F1QIR0-F1-model_v3.cif', 'AF-F1QIR0-F1-model_v3.cif', 'AF-F1QIR0-F1-model_v3.cif', 'AF-F1QIR0-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-Q9QYN5-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A813W1N3-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A671WQC1-F1-model_v3.cif', 'AF-A0A6P7K180-F1-model_v3.cif', 'AF-A0A2I3G5U7-F1-model_v3.cif', 'AF-A0A2I3G5U7-F1-model_v3.cif', 'AF-A0A2I3G5U7-F1-model_v3.cif', 'AF-A0A2Y9T2Q9-F1-model_v3.cif', 'AF-K7GIK6-F1-model_v3.cif', 'AF-A0A6P5AA61-F1-model_v3.cif', 'AF-A0A6P5AA61-F1-model_v3.cif', 'AF-A0A6P5AA61-F1-model_v3.cif', 'AF-A0A6P5AA61-F1-model_v3.cif', 'AF-A0A401T625-F1-model_v3.cif', 'AF-A0A401T625-F1-model_v3.cif', 'AF-A0A3B5MXX0-F1-model_v3.cif', 'AF-A0A3B5MXX0-F1-model_v3.cif', 'AF-A0A673KS44-F1-model_v3.cif', 'AF-A0A673KS44-F1-model_v3.cif', 'AF-A0A673KS44-F1-model_v3.cif', 'AF-A0A673KS44-F1-model_v3.cif', 'AF-A0A2J6JYK4-F1-model_v3.cif', 'AF-A0A3Q2CDH5-F1-model_v3.cif', 'AF-A0A3Q2CDH5-F1-model_v3.cif', 'AF-A0A7S0APF7-F1-model_v3.cif', 'AF-A0A7M6DP54-F1-model_v3.cif', 'AF-A0A7M6DP54-F1-model_v3.cif', 'AF-A0A7M6DP54-F1-model_v3.cif', 'AF-A0A7M6DP54-F1-model_v3.cif', 'AF-A0A6A4GFS3-F1-model_v3.cif', 'AF-Q53HC0-F1-model_v3.cif', 'AF-Q16663-F1-model_v3.cif', 'AF-Q16663-F1-model_v3.cif', 'AF-Q16663-F1-model_v3.cif', 'AF-A0A3B4A358-F1-model_v3.cif', 'AF-A0A3B4A358-F1-model_v3.cif', 'AF-A0A3B4A358-F1-model_v3.cif', 'AF-A0A3B4A358-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-A0A3Q3M453-F1-model_v3.cif', 'AF-O35903-F1-model_v3.cif', 'AF-O35903-F1-model_v3.cif', 'AF-O35903-F1-model_v3.cif', 'AF-O35903-F1-model_v3.cif', 'AF-O35903-F1-model_v3.cif', 'AF-A0A6P7X7F3-F1-model_v3.cif', 'AF-A0A6P7X7F3-F1-model_v3.cif', 'AF-A0A6P7X7F3-F1-model_v3.cif', 'AF-A0A6P7X7F3-F1-model_v3.cif', 'AF-A0A6P7X7F3-F1-model_v3.cif', 'AF-A0A7R9GC30-F1-model_v3.cif', 'AF-A0A7R9GC30-F1-model_v3.cif', 'AF-A0A7R9GC30-F1-model_v3.cif', 'AF-A0A7R9GC30-F1-model_v3.cif', 'AF-A0A7R9GC30-F1-model_v3.cif', 'AF-E9HAT7-F1-model_v3.cif', 'AF-E9HAT7-F1-model_v3.cif', 'AF-E9HAT7-F1-model_v3.cif', 'AF-E9HAT7-F1-model_v3.cif', 'AF-E9HAT7-F1-model_v3.cif', 'AF-A0A2G8LF67-F1-model_v3.cif', 'AF-A0A1X7TVT9-F1-model_v ...

# %%
fo = open('../homo_sapiens/human-immune-go-repId_sapId_sapGO_lca_sapGOFunc.tsv', 'w')

for i in range(len(output['lca_taxon'])):
    goid = output['GO_function'][i]
    fo.write(f"{output['repId'][i]}\t{output['sapId'][i]}\t{output['GO_function'][i]}\t{output['lca_taxon'][i]}\t{godag[goid].name}\n")
fo.close()
